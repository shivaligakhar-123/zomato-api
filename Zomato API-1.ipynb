# %% [markdown]
# ### Ans 1

# %%
#399720f6f904f106e162cd2bd0011a6f
import requests
import json
response=requests.get('https://developers.zomato.com/api/v2.1/cuisines',headers={'user-key':'399720f6f904f106e162cd2bd0011a6f'}
                                                                                ,params={'city_id':1})
data=response.json()
ans=data['cuisines']
for i in ans:
    if i['cuisine']['cuisine_name']=='Mexican':
        print(i['cuisine']['cuisine_id'])
# Out:
# 73

# %% [markdown]
# ### Ans 2

# %%
import requests
import json
response=requests.get('https://developers.zomato.com/api/v2.1/locations',headers={'user-key':'399720f6f904f106e162cd2bd0011a6f'}
                                                                                ,params={'query':'Connaught Place'})
data=response.json()
ans=data['location_suggestions']
for i in ans:
    print(i['entity_type'],i['entity_id'])
# Out:
# subzone 104

# %% [markdown]
# ### Ans 3

# %%
import requests
import json
response=requests.get('https://developers.zomato.com/api/v2.1/location_details',headers={'user-key':'399720f6f904f106e162cd2bd0011a6f'}
                                                                                ,params={'entity_type':'subzone','entity_id':104})
data=response.json()
ans=data['best_rated_restaurant']

for i in ans:
    print(i['restaurant']['name'],i['restaurant']['user_rating']['aggregate_rating'],i['restaurant']['R']['res_id'])
# Out:
# The Big Chill Cafe 4.8 18919107
# Haldiram's 4.2 2298
# Natural Ice Cream 4.8 310143
# Nando's 4.2 309955
# Wenger's 4.8 4249
# Dhaba - Estd 1986 Delhi 3.7 19176919
# Chili's Grill & Bar 4.5 18537536
# Xero Degrees 4.3 18729557
# Biryani By Kilo 4.4 18658316
# Yeti - The Himalayan Kitchen 4.1 19129306

# %% [markdown]
# ### Ans 4

# %%
import requests
import json
response=requests.get('https://developers.zomato.com/api/v2.1/categories',headers={'user-key':'399720f6f904f106e162cd2bd0011a6f'})
data=response.json()
ans=data['categories']
for i in ans:
    if i['categories']['name']=='Cafes':
        print(i['categories']['id'])
# Out:
# 6

# %% [markdown]
# ### Ans 5

# %%
import requests
import json
response=requests.get('https://developers.zomato.com/api/v2.1/location_details',headers={'user-key':'399720f6f904f106e162cd2bd0011a6f'}
                                                                                ,params={'entity_type':'subzone','entity_id':104})
data=response.json()
ans=data['best_rated_restaurant']
ans
# for i in ans:
#     if i['restaurant']['cuisines']=='mexican':
#         print(i['restaurant']['name'],i['restaurant']['user_rating']['aggregate_rating'],i['restaurant']['R']['res_id'])
# Out:
# [{'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#     'res_id': 18919107,
#     'is_grocery_store': False},
#    'apikey': '399720f6f904f106e162cd2bd0011a6f',
#    'id': '18919107',
#    'name': 'The Big Chill Cafe',
#    'url': 'https://www.zomato.com/ncr/the-big-chill-cafe-connaught-place-new-delhi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#    'location': {'address': 'First Floor, B 40, The Colonnade, Opposite Gate 2 Rajiv Chowk Metro Station, Connaught Place, New Delhi',
#     'locality': 'The Colonnade, Connaught Place',
#     'city': 'New Delhi',
#     'city_id': 1,
#     'latitude': '28.6345239106',
#     'longitude': '77.2190363333',
#     'zipcode': '',
#     'country_id': 1,
#     'locality_verbose': 'The Colonnade, Connaught Place, New Delhi'},
#    'switch_to_order_menu': 0,
#    'cuisines': 'Cafe',
#    'timings': '12 Noon to 11:30 PM',
#    'average_cost_for_two': 1500,
#    'price_range': 3,
#    'currency': 'Rs.',
# ...

# %% [markdown]
# ### Ans 6

# %%
import requests
import json

response=requests.get('https://developers.zomato.com/api/v2.1/search'
                      ,headers={'user-key':'399720f6f904f106e162cd2bd0011a6f'},
                      params={'entity_id':74,'entity_type':'subzone','q':'pa pa ya','category':'11','cuisines':3,'lat':28.63576,'lon':77.22445})
ans=response.json()
data=ans['restaurants']

print(data[0]['restaurant']['user_rating']['aggregate_rating'])
print( data[0]['restaurant']['average_cost_for_two'])
print( data[0]['restaurant']['cuisines'])
print(data[0]['restaurant']['location']['address'])
# Out:
# 4.9
# 2500
# Asian, Chinese, Thai, Japanese
# A-3, Select Citywalk, District Centre, Saket, New Delhi

# %% [markdown]
# ### Ans 7

# %%
import requests
import json

response=requests.get('https://developers.zomato.com/api/v2.1/search'
                      ,headers={'user-key':'399720f6f904f106e162cd2bd0011a6f'},
                      params={'entity_id':74,'entity_type':'subzone','q':'pa pa ya','category':'11','cuisines':3,'lat':28.63576,'lon':77.22445})
ans=response.json()
data=ans['restaurants']

if data[0]['restaurant']['is_table_reservation_supported']==1:
    print("yes")
else:
    print("no")
# Out:
# yes

# %% [markdown]
# ### Ans 8

# %%
import requests
import json

response=requests.get('https://developers.zomato.com/api/v2.1/search'
                      ,headers={'user-key':'399720f6f904f106e162cd2bd0011a6f'},
                      params={'entity_id':74,'entity_type':'subzone','q':'pa pa ya','category':'11','cuisines':3,'lat':28.63576,'lon':77.22445})
ans=response.json()
data=ans['restaurants']
res_id=data[0]['restaurant']['R']['res_id']
response1=requests.get('https://developers.zomato.com/api/v2.1/reviews'
                      ,headers={'user-key':'399720f6f904f106e162cd2bd0011a6f'},
                      params={'res_id':res_id})
data1=response1.json()
ans1=data1['user_reviews']
ans1
for i in ans1:
    print(i['review']['user']['name'],i['review']['rating'],i['review']['review_text'])
# Out:
# Shweta Kumar 4
# Hungry Wolfs 5 This place serves amazing food the ambiance is super good you can go on dates chill out with friends and family kitty’s aswell
# Rushil Badhwar 4
# Anushri Tripathi 5
# TheProud_Glutton 5 The best place to try so many different types of dimsums😋

# %% [markdown]
# ### Ans 9

# %%
import requests
import json
response=requests.get('https://developers.zomato.com/api/v2.1/cuisines',headers={'user-key':'399720f6f904f106e162cd2bd0011a6f'}
                                                                                ,params={'city_id':1})
data=response.json()
ans=data['cuisines']
for i in ans:
    if i['cuisine']['cuisine_name']=='BBQ':
        print(i['cuisine']['cuisine_id'])
# Out:
# 193

# %% [markdown]
# ### Ans 10

# %%
import requests
import json

response=requests.get('https://developers.zomato.com/api/v2.1/search'
                      ,headers={'user-key':'399720f6f904f106e162cd2bd0011a6f'},
                      params={'cuisines':193,'lat':28.6976709,'lon':77.1384382,'count':10,'sort':'real_distance'})
data=response.json()
ans=data['restaurants']
for i in ans:
    print(i['restaurant']['name'],i['restaurant']['user_rating']['aggregate_rating'],i['restaurant']['R']['res_id'],i['restaurant']['location']['locality'])
# Out:
# Themis Barbecue House 4.3 18204820 Netaji Subhash Place
# Barbeque Nation 4.6 9561 Netaji Subhash Place
# Amazings Kitchen 0 19370424 Prashant Vihar
# Moet's Barbeque 0 19238917 Alipur
# UBQ by Barbeque Nation 3.1 18889760 Rohini
# Kays Bar-Be-Que 3.9 3079 Ashok Vihar Phase 1
# Chicken Adda 0 19179179 Rohini
# 7teen BBQ Bistro Bnq 3.9 18595610 Moti Nagar
# Pishori Chicken 0 19061375 Kirti Nagar
# Hunger On Wheels 0 19054336 Vijay Nagar

# %% [markdown]
# ### Ans 11

# %%
import requests
import json

response=requests.get('https://developers.zomato.com/api/v2.1/search'
                      ,headers={'user-key':'399720f6f904f106e162cd2bd0011a6f'},
                      params={'cuisines':193,'lat':28.6976709,'lon':77.1384382,'count':1,'sort':'real_distance'})
data=response.json()
ans=data['restaurants']
res_id=ans[0]['restaurant']['R']['res_id']
response1=requests.get('https://developers.zomato.com/api/v2.1/reviews'
                      ,headers={'user-key':'399720f6f904f106e162cd2bd0011a6f'},
                      params={'res_id':res_id})
data1=response1.json()
ans1=data1['user_reviews']
ans1
for i in ans1:
    print(i['review']['user']['name'],i['review']['rating'],i['review']['review_text'])
# Out:
# Milind 4 If u are bored of Barbeque nation , this place is must try for u🤓🔥😅. It is one of the best barbeque restaurants in Delhi offering rooftop seating . So we opted for rooftop seating for our lunch & the view was amazing 🔥😻. We opted for veg buffet which included a range of starters like crispy corn , paneer tikka , spicy mushroom . Then in main course we tried manchurian with noodles . As a complementary drink I ordered Kiwi mojito which was so refreshing & eye catchy too😻🔥🔥🔥🤓🤓. So if u visit Pitampura next time don't miss this amazing place.👻🔥🤓😻😻
# Shashank Agarwal 4 Great place for an experience of grill in north delhi. Great starters, nice main course and average dessert.
# ...

# %% [markdown]
# ### Ans 12

# %%
import requests
import json

response=requests.get('https://developers.zomato.com/api/v2.1/search'
                      ,headers={'user-key':'399720f6f904f106e162cd2bd0011a6f'},
                      params={'lat':28.6976709,'lon':77.1384382,'count':10,'radius':4000.0,'sort':'rating','order':'desc'})
data=response.json()
ans=data['restaurants']
for i in ans:
    print(i['restaurant']['name'],i['restaurant']['user_rating']['aggregate_rating'],i['restaurant']['R']['res_id'],i['restaurant']['location']['locality'])
# Out:
# Indian Accent 4.9 2004 The Lodhi, Lodhi Road
# Pa Pa Ya 4.9 18429148 Select Citywalk Mall, Saket
# The Big Chill 4.9 1614 Khan Market
# Kuremal Mohan Lal Kulfi Wale 4.9 303642 Chawri Bazar
# Dum-Pukht - ITC Maurya 4.9 2744 ITC Maurya, Chanakyapuri
# The Big Chill 4.9 8244 Khan Market
# Wenger's 4.8 4249 Connaught Place
# Manhattan Bar & Brewery 4.8 303960 Global Foyer Mall, Golf Course Road
# Natural Ice Cream 4.8 310143 Connaught Place
# Downtown - Diners & Living Beer Cafe 4.8 4959 Sector 29
